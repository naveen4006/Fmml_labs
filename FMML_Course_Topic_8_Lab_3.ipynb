# %% [markdown]
# <a href="https://colab.research.google.com/github/naveen4006/Fmml_ASSIGNMENT_AND_labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-03 07:39:08--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   189MB/s    in 0.4s
#
# 2024-04-03 07:39:09 (189 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22198  1507.05117v1  Approximate Bayesian computation (ABC) using a...  stat
# 8018   1802.05405v1  We seek to (i) characterize the learning archi...    cs
# 7987   1707.08101v2  Learning to act in unstructured environments, ...    cs
# 10545   1207.4748v1  The problem of hierarchical clustering items f...  stat
# 7052   1709.06123v1  We present a probabilistic framework for nonli...  stat
# ...             ...                                                ...   ...
# 25376  1508.01722v2  In this paper, we present an algorithm for unc...    cs
# 21563   1012.3407v1  Translating potential disease biomarkers betwe...  stat
# 11181   1411.6622v1  This dissertation shows that careful injection...  stat
# 37955   1301.3514v1  We introduce the anti-profile Support Vector M...  stat
# 7044   1709.05545v3  Tree ensembles are flexible predictive models ...  stat
#
#                                                    title  year  \
# 22198  Fast Approximate Bayesian Computation for Esti...  2015
# 8018   Putting a bug in ML: The moth olfactory networ...  2018
# 7987   Learning to Singulate Objects using a Push Pro...  2017
# 10545  Hierarchical Clustering using Randomly Selecte...  2012
# 7052   A Probabilistic Framework for Nonlinearities i...  2017
# ...                                                  ...   ...
# 25376  Unconstrained Face Verification using Deep CNN...  2015
# 21563  Translating biomarkers between multi-way time-...  2010
# 11181  Noise Benefits in Expectation-Maximization Alg...  2014
# 37955  Anomaly Classification with the Anti-Profile S...  2013
# 7044                          Relevant Ensemble of Trees  2017
#
#                                                 keywords
# 22198  [approximate, computation, sequential, compreh...
# 8018   [characterize, architectures, exploited, biolo...
# 7987   [unstructured, environments, cluttered, substa...
# 10545  [hierarchical, clustering, similarities, scien...
# 7052   [probabilistic, framework, nonlinearities, tru...
# ...                                                  ...
# 25376  [algorithm, unconstrained, verification, convo...
# 21563  [translating, potential, biomarkers, experimen...
# 11181  [dissertation, injection, substantially, expec...
# 37955  [introduce, algorithm, classification, extensi...
# 7044   [ensembles, predictive, variables, interaction...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22198    [approximate, computation, sequential, compreh...
# 8018     [characterize, architectures, exploited, biolo...
# 7987     [unstructured, environments, cluttered, substa...
# 10545    [hierarchical, clustering, similarities, scien...
# 7052     [probabilistic, framework, nonlinearities, tru...
#                                ...
# 10202    [techniques, developed, performance, efficienc...
# 1651     [benefited, initializing, pretrained, supervis...
# 27559    [computational, accelerate, processing, recurr...
# 17759    [generation, description, framework, significa...
# 22777    [hypothesis, challenging, dimensional, hypothe...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8788 words.
# Out of those 4519 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d9dd6e1a-955e-4b00-9b25-38c6e2c63581" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9dd6e1a-955e-4b00-9b25-38c6e2c63581")) {                    Plotly.newPlot(                        "d9dd6e1a-955e-4b00-9b25-38c6e2c63581",                        [{"x":["estimation","requirement","parameter","significantly","computational","comparably","observations","computation","demonstrate","estimated","synthetic","selection","techniques","approximate","execution","equations","performance","sequential","sensitivity","circumventing","biological","numerical","derivatives","estimates","processes","comparing","integration","generated","comprehensive","inference","parameters","described","estimating","differential","significant","interactions","collected","including","neighbors","algorithmic","structures","widespread","plasticity","limitations","intrinsic","characterize","outperforms","architectures","mechanisms","architecture","exploited","complementary","illustrates","competitive","convolutional","potentially","substantially","structural","alternative","successfully","interaction","challenge","substantial","manipulation","segmented","separates","autonomous","cluttered","organized","arbitrary","generalize","unstructured","selecting","configurations","environments","experiments","meaningful","applications","similarities","developed","similarity","reconstructing","reconstruct","hierarchical","disciplines","clustering","measurements","applicable","recovered","expectation","networking","scientific","available","obtaining","characterized","restricted","stochastic","distributions","nonlinearities","alongside","truncated","graphical","truncation","integrates","improvements","extensive","probabilistic","framework","appropriately","boltzmann","integrated","distribution","nonlinear","interface","optimization","efficient","posterior","extremely","experimental","knowledge","algorithm","according","simulated","extending","practitioners","traditionally","initialization","randomized","uniformly","justification","supervised","initialize","information","theoretical","statistical","translation","equivalent","corresponding","processed","individual","languages","published","surprisingly","objective","establishment","importance","consideration","comparison","evaluation","appreciated","connection","bioinformatics","standards","development","parallels","generally","contaminated","guaranteed","challenging","retrieval","magnitude","corruption","complexity","nonconvex","wirtinger","corroborate","precision","recovering","empirical","algorithms","incremental","usefulness","perspectives","extension","demonstrated","correctness","embeddings","practical","dimensional","different","retaining","communication","approximation","distributed","dependences","projections","distributing","cardiovascular","therefore","developments","influenced","hemodynamic","validation","solutions","measurement","morphology","important","exploration","assessment","acquisition"],"y":[188,33,125,247,306,11,90,163,577,60,139,142,353,112,26,24,918,76,26,1,41,89,10,58,109,80,53,172,63,206,223,67,64,27,242,68,72,229,23,43,146,14,7,69,40,42,243,110,40,227,29,44,6,130,370,44,39,69,94,89,80,149,41,16,15,8,58,10,15,73,50,23,43,23,81,606,48,423,38,190,147,20,32,116,10,157,58,43,9,35,2,24,315,26,31,52,122,118,2,5,2,61,3,25,103,164,162,545,8,20,57,212,52,41,317,392,49,51,428,369,829,100,67,30,15,25,19,22,13,5,216,5,649,159,144,93,54,111,37,123,96,38,30,177,2,88,28,135,249,0,61,8,6,116,0,80,5,35,271,78,52,4,248,15,0,2,63,23,164,614,31,34,14,77,89,19,86,162,162,738,12,69,115,87,3,13,1,6,145,20,10,2,49,169,29,20,359,49,44,45],"type":"bar"},{"x":["estimation","requirement","parameter","significantly","comp ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4519,), (4519, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7966666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Method</span> <span style=''>for</span> <span style=''>Speeding</span> <span style=''>Up</span> <span style=''>Value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Iteration</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Partially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Observable</span> <span style=''>Markov</span> <span style=''>Decision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processes</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>for</span> <span style=''>speeding</span> <span style=''>up</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.311178247734139);'>convergence</span> <span style=''>of</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observable</span> <span style=''>Markov</span> <span style='background-color:rgba(0, 255, 0, 0.3023255813953489);'>decisions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>(POMDPs)</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>idea</span> <span style=''>is</span> <span style=''>similar</span> <span style=''>to</span> <span style=''>that</span> <span style=''>behind</span> <span style=''>modified</span> <span style=''>policy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>for</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observable</span> <span style=''>Markov</span> <span style=''>decision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>(MDPs)</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incorporated</span> <span style=''>into</span> <span style=''>any</span> <span style=''>existing</span> <span style=''>POMDP</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Experiments</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.4086956521739131);'>conducted</span> <span style=''>on</span> <span style=''>several</span> <span style=''>test</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>one</span> <span style=''>POMDP</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incremental</span> <span style=''>pruning</span> <span style=''>We</span> <span style=''>find</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>can</span> <span style=''>make</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incremental</span> <span style=''>pruning</span> <span style=''>run</span> <span style=''>several</span> <span style=''>orders</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>magnitude</span> <span style=''>faster</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Multiple</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>Models</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>multiple</span> <span style=''>kernel</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>The</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>select</span> <span style=''>the</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>kernel</span> <span style=''>matrices</span> <span style=''>that</span> <span style=''>best</span> <span style=''>explains</span> <span style=''>the</span> <span style=''>data</span> <span style=''>and</span> <span style=''>by</span> <span style=''>doing</span> <span style=''>so</span> <span style=''>improve</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalisation</span> <span style=''>on</span> <span style=''>unseen</span> <span style=''>data</span> <span style=''>Sparsity</span> <span style=''>in</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>weights</span> <span style=''>is</span> <span style=''>obtained</span> <span style=''>by</span> <span style=''>adopting</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style=''>Bayesian</span> <span style=''>approach</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>priors</span> <span style=''>are</span> <span style=''>imposed</span> <span style=''>over</span> <span style=''>the</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalised</span> <span style=''>inverse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Gaussians</span> <span style=''>on</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>weights</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construction</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>imposing</span> <span style=''>a</span> <span style=''>product</span> <span style=''>of</span> <span style=''>heavy</span> <span style=''>tailed</span> <span style=''>process</span> <span style=''>priors</span> <span style=''>over</span> <span style=''>function</span> <span style=''>space</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>derived</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>and</span> <span style=''>binary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>Learning</span> <span style=''>Method</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style=''>Networks</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.6307692307692307);'>Qualitative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Influences</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.6307692307692307);'>qualitative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influences</span> <span style=''>This</span> <span style=''>method</span> <span style=''>extends</span> <span style=''>our</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>from</span> <span style=''>networks</span> <span style=''>of</span> <span style=''>binary</span> <span style='background-color:rgba(255, 0, 0, 0.30715935334872996);'>variables</span> <span style=''>to</span> <span style=''>networks</span> <span style=''>of</span> <span style=''>discrete</span> <span style='background-color:rgba(255, 0, 0, 0.30715935334872996);'>variables</span> <span style=''>with</span> <span style=''>ordered</span> <span style=''>values</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specified</span> <span style='background-color:rgba(0, 255, 0, 0.6307692307692307);'>qualitative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influences</span> <span style='background-color:rgba(0, 255, 0, 0.3877551020408163);'>correspond</span> <span style=''>to</span> <span style=''>certain</span> <span style=''>order</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restrictions</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>in</span> <span style=''>the</span> <span style=''>network</span> <span style=''>These</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>may</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>therefore</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimated</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.5965665236051503);'>likelihood</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>isotonic</span> <span style='background-color:rgba(255, 0, 0, 0.5034802784222738);'>regression</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.5965665236051503);'>likelihood</span> <span style='background-color:rgba(255, 0, 0, 0.340909090909091);'>estimates</span> <span style=''>are</span> <span style=''>fairly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complicated</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>whereas</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>isotonic</span> <span style='background-color:rgba( ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>bandits</span> <span style=''>with</span> <span style=''>adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discretization</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximizing</span> <span style=''>a</span> <span style=''>black</span> <span style=''>box</span> <span style=''>function</span> <span style=''>fmathcalX</span> <span style=''>to</span> <span style=''>mathbbR</span> <span style=''>is</span> <span style=''>studied</span> <span style=''>in</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>with</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>(GP)</span> <span style=''>prior</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>and</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>its</span> <span style=''>simple</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cumulative</span> <span style=''>regret</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>established</span> <span style=''>The</span> <span style=''>query</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>rule</span> <span style=''>in</span> <span style=''>most</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>involves</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exhaustive</span> <span style=''>search</span> <span style=''>over</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasingly</span> <span style=''>fine</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>uniform</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discretizations</span> <span style=''>of</span> <span style=''>mathcalX</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>in</span> <span style=''>contrast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adaptively</span> <span style=''>refines</span> <span style=''>mathcalX</span> <span style=''>which</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style=''>lower</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particularly</span> <span style=''>when</span> <span style=''>mathcalX</span> <span style=''>is</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclidean</span> <span style=''>space</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>gains</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficient</span> <span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08130372492836677)
# 	automatic (0.07055873925501432)
# 	knowledge (0.13216332378223497)
# 	processing (0.10888252148997135)
# 	segmentation (0.07915472779369627)
# 	experimental (0.15329512893982808)
# 	detection (0.1303724928366762)
# 	different (0.26432664756446994)
# 	convolutional (0.13252148997134672)
# 	recognition (0.1400429799426934)
#
# Some Statistics words are:
# 	theoretical (0.14193227091633467)
# 	variables (0.1409362549800797)
# 	stochastic (0.1339641434262948)
# 	statistical (0.14392430278884463)
# 	algorithm (0.3934262948207171)
# 	distribution (0.175796812749004)
# 	estimation (0.1688247011952191)
# 	inference (0.19123505976095617)
# 	regression (0.16135458167330677)
# 	dimensional (0.18874501992031872)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="50016e14-e534-42d5-9217-3a2addb64ace" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50016e14-e534-42d5-9217-3a2addb64ace")) {                    Plotly.newPlot(                        "50016e14-e534-42d5-9217-3a2addb64ace",                        [{"x":["estimation","requirement","parameter","significantly","computational","comparably","observations","computation","demonstrate","estimated","synthetic","selection","techniques","approximate","execution","equations","performance","sequential","sensitivity","circumventing","biological","numerical","derivatives","estimates","processes","comparing","integration","generated","comprehensive","inference","parameters","described","estimating","differential","significant","interactions","collected","including","neighbors","algorithmic","structures","widespread","plasticity","limitations","intrinsic","characterize","outperforms","architectures","mechanisms","architecture","exploited","complementary","illustrates","competitive","convolutional","potentially","substantially","structural","alternative","successfully","interaction","challenge","substantial","manipulation","segmented","separates","autonomous","cluttered","organized","arbitrary","generalize","unstructured","selecting","configurations","environments","experiments","meaningful","applications","similarities","developed","similarity","reconstructing","reconstruct","hierarchical","disciplines","clustering","measurements","applicable","recovered","expectation","networking","scientific","available","obtaining","characterized","restricted","stochastic","distributions","nonlinearities","alongside","truncated","graphical","truncation","integrates","improvements","extensive","probabilistic","framework","appropriately","boltzmann","integrated","distribution","nonlinear","interface","optimization","efficient","posterior","extremely","experimental","knowledge","algorithm","according","simulated","extending","practitioners","traditionally","initialization","randomized","uniformly","justification","supervised","initialize","information","theoretical","statistical","translation","equivalent","corresponding","processed","individual","languages","published","surprisingly","objective","establishment","importance","consideration","comparison","evaluation","appreciated","connection","bioinformatics","standards","development","parallels","generally","contaminated","guaranteed","challenging","retrieval","magnitude","corruption","complexity","nonconvex","wirtinger","corroborate","precision","recovering","empirical","algorithms","incremental","usefulness","perspectives","extension","demonstrated","correctness","embeddings","practical","dimensional","different","retaining","communication","approximation","distributed","dependences","projections","distributing","cardiovascular","therefore","developments","influenced","hemodynamic","validation","solutions","measurement","morphology","important","exploration","assessment","acquisition","definition","understanding","performed","simulation","qualitative","understand","resonance","inspection","visualization","considerable","characteristics","quantitative","challenges","possibilities","increased","considerably","approaches","diagnosis","concerning","autoregressive","regression","dependencies","benchmarks","application","typically","achieving","computationally","decompose","demanding","tractable","conditionals","outperforming","predictive","representational","behaviors","interestingly","expressed","implemented","expressive","implement","optimizes","syntactic","conducted","dependent","relevance","effectiveness","relationship","fundamental","weighting","embedding","naturally","assumptions","remaining","hy ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	appreciated
# 	parallels
# 	wirtinger
# 	subtleties
# 	dobrushins
# 	coalescent
# 	heteroskedastic
# 	mcallester
# 	intersect
# 	bivariate
# 	distributionally
# 	linearization
# 	frequentist
# 	generically
# 	predictivity
# 	optimised
# 	nonconjugate
# 	exchangeability
# 	preconditioned
# 	transports
# Some words which never appear in Statistics papers:
# 	hemodynamic
# 	syntactic
# 	verification
# 	formalisms
# 	prioritizing
# 	superpixel
# 	colloquial
# 	lemmatization
# 	researches
# 	polarities
# 	sentiwordnet
# 	vietnamese
# 	retrosynthetic
# 	obstacles
# 	displacement
# 	illumination
# 	assistant
# 	outlining
# 	propositional
# 	enumerates

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0827090847436725e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7616666666666667
